# %%
# !pip install --upgrade tensorflow-hub

# %%
import tensorflow as tf
import tensorflow_hub as hub
train_data = tf.data.Dataset.from_tensor_slices((
    ["This movie was great", "Terrible film"],  # Your text data
    [1, 0]  # Your labels
))
#load the embedder. lambda to func to estab connection between keras layer and  raw tensorflow models
# return tensorflow function which can easily be integrated
hub_model = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")
model = tf.keras.Sequential([
    tf.keras.Input(shape=(), dtype=tf.string),
    tf.keras.layers.Lambda(lambda x: hub_model(x)),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
#from_logits = False because the input it is receiving is a probability
model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.BinaryCrossentropy(from_logits=False), metrics=['accuracy'],)
hist = model.fit(train_data.batch(2), epochs=10)
print(hist)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 0.6937
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.6747
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.6587
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.6434
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.6290
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.6160
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.6037
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.5916
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.5790
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.5666
# ...

# %%
# !pip install scikit-learn
# !pip install sentence_transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 43.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 25.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 22.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 53.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !pip uninstall -y torch torchvision torchaudio  # Remove existing PyTorch
# !pip install --upgrade torch torchvision torchaudio  # Reinstall PyTorch
# !pip install --upgrade sentence-transformers  # Reinstall sentence-transformers
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchvision 0.21.0+cu124
# Uninstalling torchvision-0.21.0+cu124:
#   Successfully uninstalled torchvision-0.21.0+cu124
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 38.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 33.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 40.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 6.5 MB/s eta 0:00:00
# ...

# %%
# !pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 44.8 MB/s eta 0:00:00
# ...

# %%
     #   searching for nearest neighbour for semantic similarity searches using brute and ball_tree algorithm
from sklearn.neighbors import NearestNeighbors
from sentence_transformers import SentenceTransformer
import numpy as np
import faiss
model = SentenceTransformer('all-MiniLM-L6-v2')
texts = [
    "The earth is spherical.",
    "The earth is a planet.",
    "I like to eat at a restaurant."
]
query = "the shape of earth"
texts = np.array([model.encode(text)for text in texts])
query = np.array(model.encode(query)).reshape(1,-1)

n_neighbors=2
nbrs = NearestNeighbors(n_neighbors=n_neighbors,algorithm='brute').fit(texts)
naive_distances,naive_indices = nbrs.kneighbors(query)
print(naive_distances)
print(naive_indices)
nbrs = NearestNeighbors(n_neighbors=n_neighbors,algorithm='ball_tree').fit(texts)
distances,indices = nbrs.kneighbors(query)
print(distances)
print(indices)
index = faiss.IndexFlatIP(texts.shape[1])
faiss.normalize_L2(texts)
faiss.normalize_L2(query)
index.add(texts)
s,q = index.search(query,n_neighbors)
print(s)
print(q)
# Out:
# [[0.72238213 0.84056556]]
# [[0 1]]
# [[0.72238212 0.84056553]]
# [[0 1]]
# [[0.7390821 0.6467248]]
# [[0 1]]

# %%
# !pip install tensorflow-recommenders
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 2.8 MB/s eta 0:00:00
# ...

# %%
# !pip install scann
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 30.1 MB/s eta 0:00:00
# ...

# %%
# !pip install faiss-cpu
# !pip install sentence_transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 89.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 71.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# performed ANN,HNSW and scann similarity search
from sentence_transformers import SentenceTransformer
import tensorflow as tf
import tensorflow_recommenders as tfrs
import numpy as np
import faiss
model = SentenceTransformer('all-MiniLM-L6-v2')
texts = [
    # Earth & Space (20 examples)
    "The Earth is an oblate spheroid, slightly flattened at the poles.",
    "Earth's atmosphere consists of 78% nitrogen and 21% oxygen.",
    "The Moon is Earth's only natural satellite.",
    "Earth's magnetic field protects life from solar radiation.",
    "The planet Mars is often called the Red Planet.",
    "Jupiter is the largest planet in our solar system.",
    "The Sun is a G-type main-sequence star.",
    "Black holes have extremely strong gravitational pulls.",
    "The Milky Way is our home galaxy.",
    "Light from the Sun takes about 8 minutes to reach Earth.",
    "Saturn's rings are made mostly of ice particles.",
    "Neptune is the windiest planet in the solar system.",
    "Venus has a toxic atmosphere of carbon dioxide.",
    "Mercury is the smallest planet in our solar system.",
    "Asteroids are rocky objects orbiting the Sun.",
    "Comets are icy bodies that release gas when near the Sun.",
    "The International Space Station orbits Earth every 90 minutes.",
    "NASA's Perseverance rover explores Mars.",
    "The Hubble Telescope captures deep-space images.",
    "A light-year measures distance, not time.",

    # Food & Restaurants (20 examples)
    "Italian cuisine is famous for pasta and pizza.",
    "Sushi is a traditional Japanese dish made with vinegared rice.",
    "French pastries like croissants are buttery and flaky.",
    "Mexican food often includes tacos, burritos, and salsa.",
    "Indian cuisine is known for its rich spices and curries.",
    "Thai food balances sweet, sour, spicy, and salty flavors.",
    "A steakhouse specializes in grilled meats.",
    "Vegetarian restaurants serve plant-based meals.",
    "Fine dining offers an upscale culinary experience.",
    "Fast food is convenient but often less healthy.",
    "Baking requires precise measurements and temperatures.",
    "A barista prepares coffee drinks like lattes and cappuccinos.",
    "Farm-to-table restaurants use locally sourced ingredients.",
    "Chinese dim sum includes small steamed or fried dishes.",
    "Mediterranean diets emphasize olive oil and fresh vegetables.",
    "Vegan food contains no animal products.",
    "BBQ involves slow-cooking meat over wood or charcoal.",
    "A food critic evaluates restaurants professionally.",
    "Molecular gastronomy uses science to create innovative dishes.",
    "A buffet allows diners to serve themselves.",

    # Technology (20 examples)
    "Artificial intelligence powers modern recommendation systems.",
    "Python is a popular programming language for data science.",
    "Blockchain technology enables secure digital transactions.",
    "Quantum computing could revolutionize cryptography.",
    "Neural networks mimic the human brain's structure.",
    "Self-driving cars use sensors and AI for navigation.",
    "5G networks provide faster internet speeds.",
    "Cloud computing allows remote data storage and processing.",
    "Cybersecurity protects systems from digital attacks.",
    "The Internet of Things (IoT) connects everyday devices online.",
    "Machine learning algorithms improve with more data.",
    "Augmented reality overlays digital information on the real world.",
    "Virtual reality creates immersive simulated environments.",
    "Robots are used in manufacturing and healthcare.",
    "Big data analytics helps businesses make informed decisions.",
    "A GPU accelerates computing tasks like deep learning.",
    "Open-source software allows free access to its code.",
    "Cryptocurrencies like Bitcoin operate on decentralized networks.",
    "Autonomous drones can deliver packages.",
    "Natural language processing enables chatbots to understand speech.",

    # Travel & Geography (20 examples)
    "Paris is known as the City of Light.",
    "The Great Wall of China stretches over 13,000 miles.",
    "The Amazon Rainforest is the largest tropical forest.",
    "The Eiffel Tower is a famous landmark in France.",
    "New York City is home to Times Square and Central Park.",
    "The Pyramids of Giza are ancient Egyptian structures.",
    "Tokyo is the capital of Japan and a bustling metropolis.",
    "The Grand Canyon is a massive gorge carved by the Colorado River.",
    "Venice is famous for its canals and gondolas.",
    "The Sahara Desert is the largest hot desert in the world.",
    "Mount Everest is the highest peak above sea level.",
    "The Great Barrier Reef is the world's largest coral reef system.",
    "Iceland is known for its volcanoes and geothermal springs.",
    "The Northern Lights are visible in polar regions.",
    "The Taj Mahal is a white marble mausoleum in India.",
    "Machu Picchu is an ancient Incan city in Peru.",
    "The Serengeti hosts the annual wildebeest migration.",
    "Sydney Opera House is an iconic Australian landmark.",
    "The Alps are a major mountain range in Europe.",
    "Bali is a popular Indonesian island for tourism.",

    # Miscellaneous (20 examples)
    "Reading books improves vocabulary and knowledge.",
    "Regular exercise boosts physical and mental health.",
    "Meditation helps reduce stress and improve focus.",
    "Music therapy can aid emotional healing.",
    "Dogs are loyal and make great companions.",
    "Cats are independent but affectionate pets.",
    "Sustainable living reduces environmental impact.",
    "Renewable energy sources include solar and wind power.",
    "Electric vehicles produce fewer emissions than gasoline cars.",
    "The Industrial Revolution transformed manufacturing.",
    "Democracy allows citizens to elect their leaders.",
    "The Renaissance was a period of cultural rebirth in Europe.",
    "Shakespeare wrote famous plays like Hamlet and Romeo & Juliet.",
    "Einstein's theory of relativity changed modern physics.",
    "The periodic table organizes chemical elements.",
    "DNA carries genetic information in living organisms.",
    "Vaccines help prevent infectious diseases.",
    "The human brain has about 86 billion neurons.",
    "The Internet connects billions of people worldwide.",
    "Climate change is caused by greenhouse gas emissions."
]
query = "the shape of earth"
texts = np.array([model.encode(text)for text in texts])
query = np.array(model.encode(query)).reshape(1,-1)
import faiss
M=32 #creating high degree graph:higher recall for larger index & searching time
d=768 # dimensions of the vectors/embeddings
index = faiss.IndexHNSWFlat(texts.shape[1], M)
faiss.normalize_L2(texts)
faiss.normalize_L2(query)
index.add(texts)
 #build the index using the embeddings in Snippet 9
#execute the ANN search
q = index.search(query, k=2)
print(q)
scann = tfrs.layers.factorized_top_k.ScaNN(
distance_measure= 'dot_product',
num_leaves = 1, #increase for higher number of partitions / latency for increased recall
num_leaves_to_search= 1,
num_reordering_candidates=2) # increase for higher recall but increased latency

train_data = tf.data.Dataset.from_tensor_slices(texts).take(16).enumerate().batch(1)
#takes tensor data
scann = scann.index_from_dataset(train_data)
print(scann(query, k=2))
# Out:
# (array([[0.6909351, 1.3403037]], dtype=float32), array([[ 0, 16]]))
# (<tf.Tensor: shape=(1, 2), dtype=float32, numpy=array([[0.6545325 , 0.32314917]], dtype=float32)>, <tf.Tensor: shape=(1, 2), dtype=int64, numpy=array([[0, 1]])>)

# %%
# !pip install langchain
# !pip install langchain_community
# !pip install langchain_google_genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 59.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.1/438.1 kB 34.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.0/363.0 kB 31.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 5.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.3.44
#     Uninstalling langsmith-0.3.44:
#       Successfully uninstalled langsmith-0.3.44
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.63
#     Uninstalling langchain-core-0.3.63:
#       Successfully uninstalled langchain-core-0.3.63
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 60.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-ai-generativelanguage
# ...

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate
from langchain.chains import RetrievalQA
from langchain.llms import HuggingFaceHub  # or any other open-source LLM
from langchain.schema import Document
from IPython.display import display, Markdown

# %%
# !pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 67.9 MB/s eta 0:00:00
# ...

# %%
# !pip install transformers

# %%
# prepared a RAG based chatbot
from langchain_google_genai import ChatGoogleGenerativeAI,GoogleGenerativeAIEmbeddings
import os
from google.colab import userdata
os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY_1")
texts = [
    "The earth is spherical.",
    "The earth is a planet.",
    "I like to eat at a restaurant.",
]
embedding_model  = GoogleGenerativeAIEmbeddings(
    model="models/embedding-001",          # or "text-embedding-004"
    task_type="RETRIEVAL_DOCUMENT"         # or "RETRIEVAL_QUERY"
)
doc = [Document(text) for text in texts]
vector_store = FAISS.from_documents(doc, embedding_model)
retriever = vector_store.as_retriever(search_kwargs={'k': 1})
prompt_template = """You are David, an AI knowledge bot.
Answer the questions using the facts provided. Use the provided pieces of context to answer
the users question.
If you don't know the answer, just say that "I don't know", don't try to make up an answer.
{context}"""
messages = [
    SystemMessagePromptTemplate.from_template(prompt_template),
    HumanMessagePromptTemplate.from_template("{question}")
]
prompt = ChatPromptTemplate.from_messages(messages)
# Initialize your LLM model (using HuggingFace Hub as example)

llm = ChatGoogleGenerativeAI(model = "gemini-1.5-pro",temperature = 0)

#stuff concatenate all source docs and passes to the llm
#chain_type_kwargs Allows customization of the prompt used for the QA task.
#The prompt variable should be a PromptTemplate object that structures how the question and retrieved documents are formatted before being sent to the LLM.
chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=True,
    chain_type_kwargs={"prompt": prompt}
)
#set is basically used to remove duplicate elements. happens when search>no of doucuments
def print_result(result,query):
    output_text = f"""### Question:
    {query}
    ### Answer:
    {result['result']}
    ### Source:
    {' '.join(list(set([doc.page_content for doc in result['source_documents']])))}
    """
    return output_text# Input texts
query = "What shape is the planet where humans live?"
result = chain({"query": query})
display(Markdown(print_result(result, query)))
# Out:
# <ipython-input-6-1153617047>:53: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = chain({"query": query})
# ### Question:
#     What shape is the planet where humans live?
#     ### Answer:
#     The earth is a planet, and humans live on Earth.  I don't know what shape Earth is.
#     ### Source:
#     The earth is a planet.

# %%
# Input texts
import os
from google.colab import userdata
# Update imports for newer LangChain version

from langchain.vectorstores import FAISS
from langchain.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate
from langchain.chains import RetrievalQA
# from langchain.llms import HuggingFaceHub  # Deprecated
from langchain.schema import Document
from IPython.display import display, Markdown

# Use the updated HuggingFaceEmbeddings class


# Input texts
texts = [
    "The earth is spherical.",
    "The earth is a planet.",
    "I like to eat at a restaurant."
]
doc = [Document(text) for text in texts]

# Create a FAISS vector store
vector_store = FAISS.from_documents(doc, embedding_model)
retriever = vector_store.as_retriever(search_kwargs={'k': 1})

# Define the prompt template
prompt_template = """You are David, an AI knowledge bot.
Answer the questions using the facts provided. Use the provided pieces of context to answer
the users question.
If you don't know the answer, just say that "I don't know", don't try to make up an answer.
{context}"""
messages = [
    SystemMessagePromptTemplate.from_template(prompt_template),
    HumanMessagePromptTemplate.from_template("{question}")
]
prompt = ChatPromptTemplate.from_messages(messages)

# Initialize your LLM model using the updated HuggingFaceEndpoint


# Create the RetrievalQA chain
# stuff concatenate all source docs and passes to the llm
# chain_type_kwargs Allows customization of the prompt used for the QA task.
# The prompt variable should be a PromptTemplate object that structures how the question and retrieved documents are formatted before being sent to the LLM.
chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=True,
    chain_type_kwargs={"prompt": prompt}
)

# set is basically used to remove duplicate elements. happens when search>no of doucuments
def print_result(result,query):
    output_text = f"""### Question:
    {query}
    ### Answer:
    {result['result']}
    ### Source:
    {' '.join(list(set([doc.page_content for doc in result['source_documents']])))}
    """
    return output_text

# Input texts
query = "What shape is the planet where humans live?"
result = chain.invoke({"query": query}) # Using invoke() is the recommended way in newer versions, but __call__ is still supported for now.
display(Markdown(print_result(result, query)))
# Out:
# ### Question:
#     What shape is the planet where humans live?
#     ### Answer:
#     The earth is a planet, and humans live on Earth.  I don't know what shape Earth is.
#     ### Source:
#     The earth is a planet.

# %%
# plotted  the heatmap of the confidence score for each sentence
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from sklearn.metrics.pairwise import cosine_similarity
texts = [
    "The cat sits on the mat",
    "A feline rests on the rug",
    "The sun shines brightly",
    "Dogs bark loudly at night",
    "A quick brown fox jumps",
    "The lazy dog sleeps all day"
]
#dont need documents
text = embedding_model.embed_documents(texts)
similarity_matrix = cosine_similarity(text)
#create a figure
plt.figure(figsize=(10, 8))
#create a heatmap of similarity score
#there should be annotation, format no upto 2 decimal places.colormap - orange yellow red,xlabel and ylabel should be text ,linewidths=.5
ax = sns.heatmap(
    similarity_matrix,
    annot=True,
    fmt=".2f",
    cmap="YlOrRd",
    xticklabels=texts,
    yticklabels=texts,
    linewidths=.5
)

# Rotate x-axis labels for better readability,align to the right
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
ax.set_title("Text Similarity Heatmap (Gemini Embeddings)", pad=20)

# Adjust layout so that there will be no cripping of text.
plt.tight_layout()
plt.show()

# %%
# !pip install -U -q "google-genai==1.7.0"

# %%
#training a neural network for classification of text
from google import genai
from google.genai import types
genai.__version__
from google.colab import userdata
#you defined the genai client
client = genai.Client(api_key=userdata.get("GOOGLE_API_KEY_1"))
from sklearn.datasets import fetch_20newsgroups
#import the training and testing part of the dataset
newsgroups_train = fetch_20newsgroups(subset="train")
newsgroups_test = fetch_20newsgroups(subset="test")
# View list of class names for dataset
newsgroups_train.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
newsgroups_test.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
print(newsgroups_train.data[0])
# Out:
# From: lerxst@wam.umd.edu (where's my thing)
# Subject: WHAT car is this!?
# Nntp-Posting-Host: rac3.wam.umd.edu
# Organization: University of Maryland, College Park
# Lines: 15
#
#  I was wondering if anyone out there could enlighten me on this car I saw
# the other day. It was a 2-door sports car, looked to be from the late 60s/
# early 70s. It was called a Bricklin. The doors were really small. In addition,
# the front bumper was separate from the rest of the body. This is
# all I know. If anyone can tellme a model name, engine specs, years
# of production, where this car is made, history, or whatever info you
# have on this funky looking car, please e-mail.
#
# Thanks,
# - IL
#    ---- brought to you by your neighborhood Lerxst ----

# %%
print(newsgroups_test.data[0])
# Out:
# From: v064mb9k@ubvmsd.cc.buffalo.edu (NEIL B. GANDLER)
# Subject: Need info on 88-89 Bonneville
# Organization: University at Buffalo
# Lines: 10
# News-Software: VAX/VMS VNEWS 1.41
# Nntp-Posting-Host: ubvmsd.cc.buffalo.edu
#
#
#  I am a little confused on all of the models of the 88-89 bonnevilles.
# I have heard of the LE SE LSE SSE SSEI. Could someone tell me the
# differences are far as features or performance. I am also curious to
# know what the book value is for prefereably the 89 model. And how much
# less than book value can you usually get them for. In other words how
# much are they in demand this time of year. I have heard that the mid-spring
# early summer is the best time to buy.
#
# 			Neil Gandler

# %%
import email
import re
import pandas as pd
#'''Takes raw email data (in string format) and parses it into an email message object This gives access to email headers and body through a standard interface  '''
msg = email.message_from_string(newsgroups_train.data[0])
print(msg)
# Out:
# From: lerxst@wam.umd.edu (where's my thing)
# Subject: WHAT car is this!?
# Nntp-Posting-Host: rac3.wam.umd.edu
# Organization: University of Maryland, College Park
# Lines: 15
#
#  I was wondering if anyone out there could enlighten me on this car I saw
# the other day. It was a 2-door sports car, looked to be from the late 60s/
# early 70s. It was called a Bricklin. The doors were really small. In addition,
# the front bumper was separate from the rest of the body. This is
# all I know. If anyone can tellme a model name, engine specs, years
# of production, where this car is made, history, or whatever info you
# have on this funky looking car, please e-mail.
#
# Thanks,
# - IL
#    ---- brought to you by your neighborhood Lerxst ----

# %%
newsgroups_train.target
# Out:
# array([7, 4, 4, ..., 3, 1, 8])

# %%
#preprocess the data.
def preprocess_newsgroup_row(data):
  msg = email.message_from_string(data)
  #make a string which has subject and content through message.get_payload
  text = f"{msg['Subject']}\n\n{msg.get_payload()}"
  #remove useless email id
  text = re.sub(r"[\w\.-]+@[\w\.-]+", "", text)
  # Truncate each entry to 5,000 characters
  text = text[:5000]
  return text
def preprocess_newsgroup_data(newsgroup_dataset):
  df = pd.DataFrame({"Text":newsgroup_dataset.data, "Label": newsgroup_dataset.target})
  df["Text"] = df["Text"].apply(preprocess_newsgroup_row)
  df["Class Name"] = df["Label"].map(lambda l: newsgroup_dataset.target_names[l])
  return df
# Apply preprocessing function to training and test datasets
df_train = preprocess_newsgroup_data(newsgroups_train)
df_test = preprocess_newsgroup_data(newsgroups_test)
df_train.head()
# Out:
#                                                 Text  Label  \
# 0  WHAT car is this!?\n\n I was wondering if anyo...      7
# 1  SI Clock Poll - Final Call\n\nA fair number of...      4
# 2  PB questions...\n\nwell folks, my mac plus fin...      4
# 3  Re: Weitek P9000 ?\n\nRobert J.C. Kyanko () wr...      1
# 4  Re: Shuttle Launch Question\n\nFrom article <>...     14
#
#               Class Name
# 0              rec.autos
# 1  comp.sys.mac.hardware
# 2  comp.sys.mac.hardware
# 3          comp.graphics
# 4              sci.space

# %%
df_test.head()
# Out:
#                                                 Text  Label  \
# 0  Need info on 88-89 Bonneville\n\n\n I am a lit...      7
# 1  X-Face?\n\nI'm not familiar at all with the fo...      5
# 2  Re: STRONG & weak Atheism\n\n (Turin Turambar,...      0
# 3  Re: Saudi clergy condemns debut of human right...     17
# 4  Re: After 2000 years, can we say that Christia...     19
#
#               Class Name
# 0              rec.autos
# 1         comp.windows.x
# 2            alt.atheism
# 3  talk.politics.mideast
# 4     talk.religion.misc

# %%
def sample_data(df, num_samples, classes_to_keep):
  #groupby set label as index and groups according to it. sample just samples the data. select random set from it
  #reset_index make index again a part of column
  #2nd line- we keep those classnames which has sci in it
  #astype just change the name.`
  df = df.groupby("Label").apply(lambda x: x.sample(num_samples)).reset_index(drop=True)
  df = df[df["Class Name"].str.contains(classes_to_keep)]
  df["Class Name"] = df["Class Name"].astype("category")
  df["Encoded Label"] = df["Class Name"].cat.codes
  return df
TRAIN_NUM_SAMPLES = 100
TEST_NUM_SAMPLES = 25
# Class name should contain 'sci' to keep science categories.
# Try different labels from the data - see newsgroups_train.target_names
CLASSES_TO_KEEP = "sci"
df_train = sample_data(df_train, TRAIN_NUM_SAMPLES, CLASSES_TO_KEEP)
df_test = sample_data(df_test, TEST_NUM_SAMPLES, CLASSES_TO_KEEP)
df_train.head()
# Out:
# /tmp/ipython-input-9-3401091795.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("Label").apply(lambda x: x.sample(num_samples)).reset_index(drop=True)
# /tmp/ipython-input-9-3401091795.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("Label").apply(lambda x: x.sample(num_samples)).reset_index(drop=True)
# ...

# %%
df_test.head()
# Out:
#                                                   Text  Label Class Name  \
# 275  Re: Clipper Not Good Enough for Government?\n\...     11  sci.crypt
# 276  Re: Hearing on 29 April 1993\n\nIn article <> ...     11  sci.crypt
# 277  Re: I have seen the lobby, and it is us\n\n1) ...     11  sci.crypt
# 278  Re: S1, S2\n\n\n>>>>> In article <1r60ue$>,\n>...     11  sci.crypt
# 279  Re: Hearing on 29 April 1993\n\nIn article <> ...     11  sci.crypt
#
#      Encoded Label
# 275              0
# 276              0
# 277              0
# 278              0
# 279              0

# %%
df_train.value_counts("Class Name")
# Out:
# Class Name
# sci.crypt          100
# sci.electronics    100
# sci.med            100
# sci.space          100
# Name: count, dtype: int64

# %%
df_test.value_counts("Class Name")
# Out:
# Class Name
# sci.crypt          25
# sci.electronics    25
# sci.med            25
# sci.space          25
# Name: count, dtype: int64

# %%
# !pip install torch

# %%
# !pip install langchain_community langchain-google-genai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 33.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 62.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 43.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.9/438.9 kB 29.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 367.7/367.7 kB 26.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 105.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.5/585.5 kB 32.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 10.6 MB/s eta 0:00:00
# ...

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
import os
from google.colab import userdata
os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY_1")
os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get("HUGGINGFACEHUB_API_TOKEN")
embedding_model = GoogleGenerativeAIEmbeddings(
    model="models/embedding-001",          # or "text-embedding-004"
    task_type="RETRIEVAL_DOCUMENT"         # or "RETRIEVAL_QUERY"
)
from transformers import AutoTokenizer, AutoModel
import torch

# Load model and tokenizer
model_name = "bert-base-uncased"  # or any HF model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

def get_embedding(text):
    # Tokenize input
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)

    # Generate embeddings
    with torch.no_grad():
        outputs = model(**inputs)

    # Use mean pooling for sentence embedding
    last_hidden_states = outputs.last_hidden_state
    return last_hidden_states.mean(dim=1).squeeze().numpy()
def create_embeddings(df):
    df["Embeddings"] = df["Text"].apply(get_embedding)
    return df
df_train = create_embeddings(df_train)
df_test = create_embeddings(df_test)
df_train.head()
df_test.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
#                                                   Text  Label Class Name  \
# 275  Re: Clipper Not Good Enough for Government?\n\...     11  sci.crypt
# ...

# %%
# !pip install tensorflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 MB 591.4 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 83.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.9/319.9 kB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 121.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 109.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 108.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 16.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 5.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.31.1
#     Uninstalling protobuf-6.31.1:
#       Successfully uninstalled protobuf-6.31.1
# ...

# %%
#created a neural network
import tensorflow as tf
import tensorflow.keras.layers as tfl
import numpy as np
early_stop = tf.keras.callbacks.EarlyStopping(monitor="accuracy", patience=3)
def build_classification_model(input_size: int, num_classes: int) -> tf.keras.Model:
    return tf.keras.models.Sequential(
        [
            tfl.Input([input_size], name="embedding_inputs"),
            tfl.Dense(input_size, activation="relu", name="hidden"),
            tfl.Dense(num_classes, activation="softmax", name="output_probs"),
        ]
    )
    #iloc means integer location. here it means first element
embedding_size = len(df_train["Embeddings"].iloc[0])
classifier = build_classification_model(
    embedding_size, len(df_train["Class Name"].unique())
)
classifier.summary()
classifier.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=["accuracy"],)
import numpy as np


NUM_EPOCHS = 20
BATCH_SIZE = 32

# Split the x and y components of the train and validation subsets.
y_train = df_train["Encoded Label"]
x_train = np.stack(df_train["Embeddings"])
y_val = df_test["Encoded Label"]
x_val = np.stack(df_test["Embeddings"])
history = classifier.fit(
    x=x_train,
    y=y_train,
    validation_data=(x_val, y_val),

    batch_size=BATCH_SIZE,
    epochs=NUM_EPOCHS,
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# ...

# %%
# !pip install tensorflow_hub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 23.2 MB/s eta 0:00:00
# ...

# %%
import tensorflow_hub as hub

# Load the Universal Sentence Encoder model
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# Define the embedding function
def embed_fn(text: str) -> np.ndarray:
    return embed([text])[0]

# %%
def make_prediction(text: str) -> list[float]:
    """Infer categories from the provided text."""
    # Remember that the model takes embeddings as input, so calculate them first.
    embedded = get_embedding(text)

    # And recall that the input must be batched, so here they are wrapped as a
    # list to provide a batch of 1.
    inp = np.array([embedded])

    # And un-batched here.
    [result] = classifier.predict(inp)
    return result
# This example avoids any space-specific terminology to see if the model avoids
# biases towards specific jargon.
new_text = """
First-timer looking to get out of here.

Hi, I'm writing about my interest in travelling to the outer limits!

What kind of craft can I buy? What is easiest to access from this 3rd rock?

Let me know how to do that please.
"""

result = make_prediction(new_text)

for idx, category in enumerate(df_test["Class Name"].cat.categories):
    print(f"{category}: {result[idx] * 100:0.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# sci.crypt: 0.00%
# sci.electronics: 66.42%
# sci.med: 0.49%
# sci.space: 33.09%

# %%
#QA
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-1.5-pro",temperature=0);
response = llm.invoke("When and where is Billie Eilish's next concert?")
print(response.content)
# Out:
# I cannot provide you with Billie Eilish's *next* concert date and location.  Tour information changes frequently, and real-time data like that isn't something I can access.
#
# To find this information, I recommend checking these resources:
#
# * **Billie Eilish's Official Website:** This is the best place for official tour announcements.
# * **Ticketmaster/Live Nation/Other Ticket Vendors:** These sites list upcoming concerts and tour dates.
# * **Billie Eilish's Social Media:**  Follow her official accounts for updates.
#
#
# Good luck finding tickets!

# %%
#with ground search
from langchain_google_genai import ChatGoogleGenerativeAI
from google.generativeai.types import GenerationConfig

llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-pro",
    temperature=0,
    model_kwargs={
        "generation_config": GenerationConfig(temperature=0),
        "tools": [{"google_search": {"enable": True}}]
    }
)
response = llm.invoke("When and where is Billie Eilish's next concert?")
print(response.content)
# Out:
# I cannot provide Billie Eilish's *next* concert date and location with certainty.  Tour information changes frequently, and real-time updates are best found on official sources.
#
# To find the most up-to-date information on Billie Eilish's tour dates and locations, I recommend checking these resources:
#
# * **Billie Eilish's Official Website:** This is the most reliable source.
# * **Ticketmaster:**  A major ticket vendor that often lists tour dates.
# * **Bandsintown:** A website and app that tracks concert information.
# * **Social Media:** Check Billie Eilish's official social media accounts (Instagram, Twitter, etc.) for announcements.
