# %% [markdown]
# <a href="https://colab.research.google.com/github/rishantmallick/5-days-genai-hackathon/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.8/222.8 kB 5.8 MB/s eta 0:00:00

# %%
# running a basic llm - prompt engineering
from google import genai
from google.colab import userdata
client = genai.Client(api_key=userdata.get("GOOGLE_API_KEY_1"))
response = client.models.generate_content(
    model="gemini-1.5-pro", contents="What is quantum computing?"
)
print(response.text)
#asking question
from google import genai
from google.colab import userdata
client = genai.Client(api_key=userdata.get("GOOGLE_API_KEY_1"))
prompt = (
    "Explain how artificial intelligence mimics human learning in simple terms. "
    "Answer in 2–3 sentences using simple language suitable for beginners. Avoid technical jargon."
)
response = client.models.generate_content(
    model="gemini-1.5-pro", contents=prompt
)
print(response.text)
#sentiment analysis
from google import genai
from google.colab import userdata
client = genai.Client(api_key=userdata.get("GOOGLE_API_KEY_1"))
prompt = (
    '''Classify movie reviews as POSITIVE, NEUTRAL or NEGATIVE.
Review: "Her" is a disturbing study revealing the direction
humanity is headed if AI is allowed to keep evolving,
unchecked. I wish there were more movies like this masterpiece.
Sentiment:'''
)
response = client.models.generate_content(
    model="gemini-1.5-pro", contents=prompt
)
print(response.text)
#parsing
from google import genai
from google.colab import userdata
client = genai.Client(api_key=userdata.get("GOOGLE_API_KEY_1"))
prompt = (
    '''Parse a customer's pizza order into valid JSON:

EXAMPLE:
I want a small pizza with cheese, tomato sauce, and pepperoni.
JSON Response:
```
{
"size": "small",
"type": "normal",
"ingredients": [["cheese", "tomato sauce", "peperoni"]]
}
```
Can I get a large pizza with tomato sauce, basil and mozzarella
{
"size": "large",
"type": "normal",
"ingredients": [["tomato sauce", "bazel", "mozzarella"]]
}
Now, I would like a large pizza, with the first half cheese and
mozzarella. And the other tomato sauce, ham and pineapple.
JSON Response:'''
)
response = client.models.generate_content(
    model="gemini-1.5-pro", contents=prompt
)
print(response.text)
#sentiment analysis
from google import genai
from google.colab import userdata
client = genai.Client(api_key=userdata.get("GOOGLE_API_KEY_1"))
prompt = (
    '''Classify movie reviews as positive, neutral or negative. Only

return the label in uppercase.
Review: "Her" is a disturbing study revealing the direction
humanity is headed if AI is allowed to keep evolving,
unchecked. It's so disturbing I couldn't watch it.
Sentiment:'''
)
response = client.models.generate_content(
    model="gemini-1.5-pro", contents=prompt
)
print(response.text)
#sentiment analysis
from google import genai
from google.colab import userdata
client = genai.Client(api_key=userdata.get("GOOGLE_API_KEY_1"))
prompt = (
    '''Classify movie reviews as positive, neutral or negative. Return

valid JSON:
Review: "Her" is a disturbing study revealing the direction
humanity is headed if AI is allowed to keep evolving,
unchecked. It's so disturbing I couldn't watch it.
Schema:
```
MOVIE:
{
"sentiment": String "POSITIVE" | "NEGATIVE" | "NEUTRAL",
"name": String
}
MOVIE REVIEWS:
{
"movie_reviews": [MOVIE]
}
```
JSON Response:'''
)
response = client.models.generate_content(
    model="gemini-1.5-pro", contents=prompt
)
print(response.text)
#describe
from google import genai
from google.colab import userdata
client = genai.Client(api_key=userdata.get("GOOGLE_API_KEY_1"))
prompt = (
    '''I want you to act as a travel guide. I will write to you
about my location and you will suggest 3 places to visit near
me. In some cases, I will also give you the type of places I
will visit.
My suggestion: "I am in Amsterdam and I want to visit
only museums."
Travel Suggestions:'''
)
response = client.models.generate_content(
    model="gemini-1.5-pro", contents=prompt
)
print(response.text)
# Out:
# Quantum computing harnesses the mind-bending principles of quantum mechanics to solve problems that are too complex for classical computers.  Unlike classical computers that store information as bits representing 0 or 1, quantum computers use **qubits**.  Qubits leverage quantum phenomena like **superposition** and **entanglement** to perform calculations in a fundamentally different way.
#
# Here's a breakdown:
#
# * **Superposition:**  A qubit can exist in a superposition, meaning it can be both 0 and 1 simultaneously. This allows quantum computers to explore multiple possibilities at once, vastly increasing their computational power for certain tasks. Imagine flipping a coin – it's both heads and tails until it lands.  Superposition is like that coin spinning in the air.
#
# * **Entanglement:** Multiple qubits can be entangled, meaning their fates are linked.  Measuring the state of one instantly reveals the state of the others, regardless of the distance separating them. This interconnectedness allows for complex calculations and simulations.
#
# * **Quantum Algorithms:**  These algorithms exploit superposition and entanglement to tackle problems that are intractable for classical computers.  Examples include Shor's algorithm for factoring large numbers (a threat to current cryptography) and Grover's algorithm for searching unsorted databases.
#
# **Key Differences from Classical Computing:**
#
# * **Data Representation:** Classical computers use bits (0 or 1); quantum computers use qubits (0, 1, or both simultaneously).
# * **Processing:** Classical computers process information sequentially; quantum computers explore multiple possibilities concurrently.
# * **Capabilities:** Quantum computers excel at specific tasks like simulating quantum systems, factoring large numbers, and optimizing complex problems.  They are not meant to replace classical computers for everyday tasks.
#
# **Current State and Future Potential:**
#
# Quantum computing is still in its early stages of development.  Building and maintaining stable qubits is a significant technological challenge. However, the potential is enormous.  Quantum computers could revolutionize fields like:
#
# * **Medicine:** Designing new drugs and therapies.
# * **Materials Science:** Discovering new materials with enhanced properties.
# * **Financial Modeling:** Developing more accurate and sophisticated models.
# * **Artificial Intelligence:** Advancing machine learning algorithms.
#
# **In summary:** Quantum computing is a revolutionary paradigm shift in computation that leverages the bizarre yet powerful laws of quantum mechanics to solve incredibly complex problems beyond the reach of classical computers. While still in its nascent stages, it holds immense promise for transforming various fields in the future.
#
# Imagine teaching a dog a trick with lots of treats and practice.  AI learns similarly, by being fed tons of information and rewarded for correct answers, getting better over time.  Just like us, it learns from experience, although it does so much faster with computers.
#
# POSITIVE.  While the reviewer points out a disturbing element, they clearly admire the film, calling it a "masterpiece" and wishing for more like it.  This overrides the potentially negative aspect of the disturbing subject matter.
#
# ```json
# {
#   "size": "large",
#   "type": "half-half",
#   "ingredients": [
#     ["cheese", "mozzarella"],
#     ["tomato sauce", "ham", "pineapple"]
#   ]
# }
# ```
#
# NEGATIVE
#
# ```json
# {
#   "movie_reviews": [
#     {
#       "sentiment": "NEGATIVE",
#       "name": "Her"
#     }
#   ]
# }
# ```
#
# 1. **Rijksmuseum:**  Home to Dutch Masters like Rembrandt and Vermeer, this museum showcases the Netherlands' artistic heritage from the Middle Ages to the present day.  Don't miss "The Night Watch"!
#
# 2. **Van Gogh Museum:** Dedicated to the life and works of Vincent van Gogh, this museum boasts the largest collection of his paintings and drawings in the world.  See iconic works like "Sunflowers" and "The Potato Eaters."
#
# 3. **Anne Frank House:**  A poignant and powerful museum located in the secret annex where Anne Frank and her family hid from the Nazis during World War II.  A must-visit for its historical significance and personal story.
